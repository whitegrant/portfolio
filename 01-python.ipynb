# %%
import pandas as pd

# %%
df = pd.read_csv('../data/01-intro.csv')

# %%
df
# Out:
#     tick  year     revenue       ebit       capx        debt        mktcap
# 0    HRL  2000    3675.132    262.607    100.125     145.928  2.612287e+03
# 1    HRL  2001    4124.112    300.306     77.129     462.407  3.727245e+03
# 2    HRL  2002    3910.314    310.509     64.465     409.648  3.229432e+03
# 3    HRL  2003    4200.328    307.024     67.104     395.273  3.579150e+03
# 4    HRL  2004    4779.875    357.017     80.363     361.510  4.323667e+03
# 5    HRL  2005    5413.997    418.574    107.094     350.430  4.510167e+03
# 6    HRL  2006    5745.481    448.913    141.516     350.054  5.138992e+03
# 7    HRL  2007    6193.032    478.570    125.795     350.005  5.485607e+03
# 8    HRL  2008    6754.903    509.426    125.890     350.000  4.181068e+03
# 9    HRL  2009    6533.671    531.786     96.961     350.000  5.138035e+03
# 10   HRL  2010    7220.719    643.182     89.823       0.000  6.823936e+03
# ...
